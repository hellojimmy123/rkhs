# %%
import torch 
import s2cnn

# %%
res = s2cnn.s2_near_identity_grid(n_alpha=18)
print(len(res))
# Out:
# 54

# %%
import numpy as np 
a = np.array(res)
print( a/np.pi)
# Out:
# [[0.04166667 0.        ]
#  [0.04166667 0.11111111]
#  [0.04166667 0.22222222]
#  [0.04166667 0.33333333]
#  [0.04166667 0.44444444]
#  [0.04166667 0.55555556]
#  [0.04166667 0.66666667]
#  [0.04166667 0.77777778]
#  [0.04166667 0.88888889]
#  [0.04166667 1.        ]
#  [0.04166667 1.11111111]
#  [0.04166667 1.22222222]
#  [0.04166667 1.33333333]
#  [0.04166667 1.44444444]
#  [0.04166667 1.55555556]
#  [0.04166667 1.66666667]
#  [0.04166667 1.77777778]
#  [0.04166667 1.88888889]
#  [0.08333333 0.        ]
#  [0.08333333 0.11111111]
#  [0.08333333 0.22222222]
#  [0.08333333 0.33333333]
#  [0.08333333 0.44444444]
#  [0.08333333 0.55555556]
#  [0.08333333 0.66666667]
#  [0.08333333 0.77777778]
#  [0.08333333 0.88888889]
#  [0.08333333 1.        ]
#  [0.08333333 1.11111111]
#  [0.08333333 1.22222222]
#  [0.08333333 1.33333333]
#  [0.08333333 1.44444444]
#  [0.08333333 1.55555556]
#  [0.08333333 1.66666667]
#  [0.08333333 1.77777778]
#  [0.08333333 1.88888889]
#  [0.125      0.        ]
# ...
